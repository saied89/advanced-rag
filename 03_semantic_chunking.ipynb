# %% [markdown]
# # Semantic Chunking
#
# We will create a rolling window of sentence embedding and calculate the similary betweent the consequnce windows. Once the similarity is low, we will break the chunks as it means the semantic topic of the windows had changed.
#
# * [Loading a complex dataset of documents](#loading-a-complex-dataset-of-documents)
# * [Apply statistical chunker on the document content](#apply-statistical-chunker-on-the-document-content)
# * [Add metadata to the chunks](#add-metadata-to-the-chunks)

# %% [markdown]
# ### Visual improvements
#
# We will use [rich library](https://github.com/Textualize/rich) to make the output more readable, and supress warning messages.

# %%
from rich.pretty import pprint
from rich.theme import Theme
from rich.console import Console
from rich.panel import Panel
from rich.text import Text

custom_theme = Theme({
    "repr.own": "bright_yellow",            # Class names
    "repr.tag_name": "bright_yellow",       # Adjust tag names which might still be purple
    "repr.call": "bright_yellow",           # Function calls and other symbols
    "repr.str": "bright_green",             # String representation
    "repr.number": "bright_red",            # Numbers
    "repr.attrib_name": "bright_yellow",    # Attribute names
    "repr.attrib_value": "bright_blue"      # Attribute values
})

# Apply the theme and print the object with rich formatting

console = Console(theme=custom_theme)

# %%
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading a complex dataset of documents
#
# We will load a complex dataset of scientific documents from Arxiv. Applying naive chunks on such documents will give poor results in RAG applications.

# %%
from datasets import load_dataset

dataset = load_dataset("jamescalam/ai-arxiv2", split="train")
console.print(dataset)
# Out:
# Dataset({
#     features: ['id', 'title', 'summary', 'source', 'authors', 'categories', 'comment', 'journal_ref',
# 'primary_category', 'published', 'updated', 'content', 'references'],
#     num_rows: 2673
# })

# %%
content = dataset[3]["content"]
console.print(content[:500])
# Out:
# # Mamba: Linear-Time Sequence Modeling with Selective State Spaces
# # Albert Gu*1 and Tri Dao*2
# 1Machine Learning Department, Carnegie Mellon University 2Department of Computer Science, Princeton University
# agu@cs.cmu.edu, tri@tridao.me
# # Abstract
# Foundation models, now powering most of the exciting applications in deep learning, are almost universally based on
# the Transformer architecture and its core attention module. Many subquadratic-time architectures such as linear
# attention, gated convolut

# %% [markdown]
# ## Apply statistical chunker on the document content
#
# We will use a popular embedding encoder to encode our documents, and use a [statistical chunker](https://github.com/aurelio-labs/semantic-chunkers/tree/main) that will evaluate the semantic similarity (based on the embedding distance) across the sentences to find the best place to split into chunks.

# %%
import os
from getpass import getpass
from semantic_router.encoders import OpenAIEncoder

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass("OpenAI API key: ")

encoder = OpenAIEncoder(name="text-embedding-3-small")

# %%
from semantic_chunkers import StatisticalChunker

chunker = StatisticalChunker(
    encoder=encoder,
    min_split_tokens=100,
    max_split_tokens=500,
    plot_chunks=True,
    enable_statistics=True,
)

# %%
chunks_0 = chunker(docs=[dataset["content"][0]])
# Out:
# 2024-10-12 18:50:15 INFO semantic_chunkers.utils.logger Single document exceeds the maximum token limit of 500. Splitting to sentences before semantically merging.
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 1 length: 7
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 1 trunc length: 7
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 2 length: 21
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 2 trunc length: 21
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 3 length: 35
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 3 trunc length: 35
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 4 length: 20
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 4 trunc length: 20
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 5 length: 9
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 5 trunc length: 9
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 6 length: 441
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 6 trunc length: 441
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 7 length: 8
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 7 trunc length: 8
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 8 length: 77
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 8 trunc length: 77
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 9 length: 136
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 9 trunc length: 136
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 10 length: 124
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 10 trunc length: 124
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 11 length: 101
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document 11 trunc length: 101
# 2024-10-12 18:50:15 INFO semantic_router.utils.logger Document
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 429 trunc length: 37
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 430 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 430 trunc length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 431 length: 107
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 431 trunc length: 107
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 432 length: 9
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 432 trunc length: 9
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 433 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 433 trunc length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 434 length: 16
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 434 trunc length: 16
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 435 length: 10
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 435 trunc length: 10
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 436 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 436 trunc length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 437 length: 11
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 437 trunc length: 11
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 438 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 438 trunc length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 439 length: 12
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 439 trunc length: 12
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 440 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 440 trunc length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 441 length: 8
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 441 trunc length: 8
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 442 length: 18
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 442 trunc length: 18
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 443 length: 3
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 443 trunc length: 3
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 444 length: 14
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 444 trunc length: 14
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 445 length: 11
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 445 trunc length: 11
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 446 length: 10
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 446 trunc length: 10
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 447 length: 47
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 447 trunc length: 47
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 448 length: 120
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 448 trunc length: 120
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 449 length: 78
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 449 trunc length: 78
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 450 length: 2
# 2024-10-12 18:50:16 INFO semantic_router.utils.logger Document 450 trunc length: 2
# Chunking Statistics:
#   - Total Documents: 450
#   - Total Chunks: 46
#   - Chunks by Threshold: 40
#   - Chunks by Max Chunk Size: 5
#   - Last Chunk: 1
#   - Minimum Token Size of Chunk: 90
#   - Maximum Token Size of Chunk: 494
#   - Similarity Chunk Ratio: 0.87

# %%
console.print(chunks_0[0][:5])
# Out:
# [
#     Chunk(
#         splits=[
#             '4 2 0 2',
#             'n a J 8 ] G L . s c [',
#             '1 v 8 8 0 4 0 . 1 0 4 2 : v i X r a',
#             '# Mixtral of Experts',
#             'Albert Q.',
#             'Jiang, Alexandre Sablayrolles, Antoine Roux, Arthur Mensch, Blanche Savary, Chris Bamford, Devendra
# Singh Chaplot, Diego de las Casas, Emma Bou Hanna, Florian Bressand, Gianna Lengyel, Guillaume Bour, Guillaume
# Lample, LÃ©lio Renard Lavaud, Lucile Saulnier, Marie-Anne Lachaux, Pierre Stock, Sandeep Subramanian, Sophia Yang,
# Szymon Antoniak, Teven Le Scao, ThÃ©ophile Gervet, Thibaut Lavril, Thomas Wang, TimothÃ©e Lacroix, William El
# Sayed',
#             'Abstract',
#             'We introduce Mixtral 8x7B, a Sparse Mixture of Experts (SMoE) language model.',
#             'Mixtral has the same architecture as Mistral 7B, with the difference that each layer is composed of 8
# feedforward blocks (i.e. experts).',
#             'For every token, at each layer, a router network selects two experts to process the current state and
# combine their outputs.',
#             'Even though each token only sees two experts, the selected experts can be different at each
# timestep.',
#             'As a result, each token has access to 47B parameters, but only uses 13B active parameters during
# inference.',
#             'Mixtral was trained with a context size of 32k tokens and it outperforms or matches Llama 2 70B and
# GPT-3.5 across all evaluated benchmarks.',
#             'In particular, Mixtral vastly outperforms Llama 2 70B on mathematics, code generation, and
# multilingual benchmarks.',
#             'We also provide a model fine- tuned to follow instructions, Mixtral 8x7B â',
#             'Instruct, that surpasses GPT-3.5 Turbo, Claude-2.1, Gemini Pro, and Llama 2 70B â'
#         ],
#         is_triggered=True,
#         triggered_score=0.2768185513422623,
#         token_count=445,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             'chat model on human bench- marks.',
#             'Both the base and instruct models are released under the Apache 2.0 license.',
#             'Code: https://github.com/mistralai/mistral-src Webpage: https://mistral.ai/news/mixtral-of-experts/',
#             '# Introduction',
#             'In this paper, we present Mixtral 8x7B, a sparse mixture of experts model (SMoE) with open weights,
# licensed under Apache 2.0.',
#             'Mixtral outperforms Llama 2 70B and GPT-3.5 on most benchmarks.',
#             'As it only uses a subset of its parameters for every token, Mixtral allows faster inference speed at
# low batch-sizes, and higher throughput at large batch-sizes.',
#             'Mixtral is a sparse mixture-of-experts network.',
#             'It is a decoder-only model where the feedforward block picks from a set of 8 distinct groups of
# parameters.',
#             'At every layer, for every token, a router network chooses two of these groups (the â'
#         ],
#         is_triggered=True,
#         triggered_score=0.20194812352768995,
#         token_count=209,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             'expertsâ',
#             ') to process the token and combine their output additively.',
#             'This technique increases the number of parameters of a model while controlling cost and latency, as
# the model only uses a fraction of the total set of parameters per token.',
#             'Mixtral is pretrained with multilingual data using a context size of 32k tokens.',
#             'It either matches or exceeds the performance of Llama 2 70B and GPT-3.5, over several benchmarks.',
#             'In particular,',
#             'Mixture of Experts Layer i gating inputs af outputs router expert'
#         ],
#         is_triggered=True,
#         triggered_score=0.28744402992423285,
#         token_count=109,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             'Figure 1:',
#             'Mixture of Experts Layer.',
#             'Each input vector is assigned to 2 of the 8 experts by a router.',
#             'The layerâ',
#             's output is the weighted sum of the outputs of the two selected experts.',
#             'In Mixtral, an expert is a standard feedforward block as in a vanilla transformer architecture.',
#             'Mixtral demonstrates superior capabilities in mathematics, code generation, and tasks that require
# multilingual understanding, significantly outperforming Llama 2 70B in these domains.',
#             'Experiments show that Mixtral is able to successfully retrieve information from its context window of
# 32k tokens, regardless of the sequence length and the location of the information in the sequence.',
#             'We also present Mixtral 8x7B â',
#             'Instruct, a chat model fine-tuned to follow instructions using supervised fine-tuning and Direct
# Preference Optimization [25].',
#             'Its performance notably surpasses that of GPT-3.5 Turbo, Claude-2.1, Gemini Pro, and Llama 2 70B â',
#             'chat model on human evaluation benchmarks.',
#             'Mixtral â',
#             'Instruct also demonstrates reduced biases, and a more balanced sentiment profile in benchmarks such as
# BBQ, and BOLD.',
#             'We release both Mixtral 8x7B and Mixtral 8x7B â'
#         ],
#         is_triggered=True,
#         triggered_score=0.26784678640095494,
#         token_count=262,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             'Instruct under the Apache 2.0 license1, free for academic and commercial usage, ensuring broad
# accessibility and potential for diverse applications.',
#             'To enable the community to run Mixtral with a fully open-source stack, we submitted changes to the
# vLLM project, which integrates Megablocks CUDA kernels for efficient inference.',
#             'Skypilot also allows the deployment of vLLM endpoints on any instance in the cloud.',
#             '# 2 Architectural details',
#             'Mixtral is based on a transformer architecture [31] and uses the same modifications as described in
# [18], with the notable exceptions that Mix- tral supports a fully dense context length of 32k tokens, and the feed-
# forward blocks are replaced by Mixture-of-Expert layers (Section 2.1).',
#             'The model architecture parameters are summarized in Table 1.'
#         ],
#         is_triggered=True,
#         triggered_score=0.28466610393355046,
#         token_count=167,
#         metadata=None
#     )
# ]

# %%
chunks_1 = chunker(docs=[dataset["content"][1]])
# Out:
# 2024-10-12 18:50:19 INFO semantic_chunkers.utils.logger Single document exceeds the maximum token limit of 500. Splitting to sentences before semantically merging.
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 1 length: 7
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 1 trunc length: 7
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 2 length: 23
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 2 trunc length: 23
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 3 length: 35
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 3 trunc length: 35
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 4 length: 70
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 4 trunc length: 70
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 5 length: 110
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 5 trunc length: 110
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 6 length: 98
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 6 trunc length: 98
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document 7 length: 10
# 2024-10-12 18:50:19 INFO semantic_router.utils.logger Document
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 469 trunc length: 616
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 470 length: 306
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 470 trunc length: 306
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 471 length: 132
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 471 trunc length: 132
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 472 length: 16
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 472 trunc length: 16
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 473 length: 126
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 473 trunc length: 126
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 474 length: 25
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 474 trunc length: 25
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 475 length: 203
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 475 trunc length: 203
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 476 length: 162
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 476 trunc length: 162
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 477 length: 2
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 477 trunc length: 2
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 478 length: 6
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 478 trunc length: 6
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 479 length: 257
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 479 trunc length: 257
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 480 length: 80
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 480 trunc length: 80
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 481 length: 392
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 481 trunc length: 392
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 482 length: 306
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 482 trunc length: 306
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 483 length: 112
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 483 trunc length: 112
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 484 length: 630
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 484 trunc length: 630
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 485 length: 391
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 485 trunc length: 391
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 486 length: 97
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 486 trunc length: 97
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 487 length: 165
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 487 trunc length: 165
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 488 length: 104
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 488 trunc length: 104
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 489 length: 160
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 489 trunc length: 160
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 490 length: 357
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 490 trunc length: 357
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 491 length: 493
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 491 trunc length: 493
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 492 length: 2
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 492 trunc length: 2
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 493 length: 81
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 493 trunc length: 81
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 494 length: 788
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 494 trunc length: 788
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 495 length: 304
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 495 trunc length: 304
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 496 length: 881
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 496 trunc length: 881
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 497 length: 33
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 497 trunc length: 33
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 498 length: 108
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 498 trunc length: 108
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 499 length: 926
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 499 trunc length: 926
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 500 length: 7
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 500 trunc length: 7
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 501 length: 51
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 501 trunc length: 51
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 502 length: 8
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 502 trunc length: 8
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 503 length: 96
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 503 trunc length: 96
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 504 length: 135
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 504 trunc length: 135
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 505 length: 6
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 505 trunc length: 6
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 506 length: 85
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 506 trunc length: 85
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 507 length: 103
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 507 trunc length: 103
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 508 length: 10
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 508 trunc length: 10
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 509 length: 4
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 509 trunc length: 4
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 510 length: 84
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 510 trunc length: 84
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 511 length: 2
# 2024-10-12 18:50:20 INFO semantic_router.utils.logger Document 511 trunc length: 2
# Chunking Statistics:
#   - Total Documents: 511
#   - Total Chunks: 55
#   - Chunks by Threshold: 41
#   - Chunks by Max Chunk Size: 13
#   - Last Chunk: 1
#   - Minimum Token Size of Chunk: 1
#   - Maximum Token Size of Chunk: 499
#   - Similarity Chunk Ratio: 0.75

# %%
console.print(chunks_1[0][:3])
# Out:
# [
#     Chunk(
#         splits=[
#             '3 2 0 2',
#             'c e D 8 2 ] G L . s c [',
#             '1 v 8 3 2 7 1 . 2 1 3 2 : v i X r a',
#             '# Fast Inference of Mixture-of-Experts Language Models with Offloading',
#             'Artyom Eliseev Moscow Institute of Physics and Technology Yandex School of Data Analysis
# lavawolfiee@gmail.com',
#             '# Denis Mazur Moscow Institute of Physics and Technology Yandex Researchcore denismazur8@gmail.com'
#         ],
#         is_triggered=True,
#         triggered_score=0.30299574340000246,
#         token_count=109,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             '# Abstract',
#             'With the widespread adoption of Large Language Models (LLMs), many deep learning practitioners are
# looking for strategies of running these models more efficiently.',
#             'One such strategy is to use sparse Mixture-of-Experts (MoE) â',
#             'a type of model architectures where only a fraction of model layers are active for any given input.',
#             'This property allows MoE-based language models to generate tokens faster than their â',
#             'denseâ',
#             'counterparts, but it also increases model size due to having multiple â',
#             'expertsâ',
#             '.',
#             'Unfortunately, this makes state-of-the-art MoE language models difficult to run without high-end
# GPUs.',
#             'In this work, we study the problem of running large MoE language models on consumer hardware with
# limited accelerator memory.',
#             'We build upon parameter offloading algorithms and propose a novel strategy that accelerates offloading
# by taking advantage of innate properties of MoE LLMs.',
#             'Using this strategy, we build can run Mixtral-8x7B with mixed quantization on desktop hardware and
# free-tier Google Colab instances.'
#         ],
#         is_triggered=True,
#         triggered_score=0.26662330218875296,
#         token_count=204,
#         metadata=None
#     ),
#     Chunk(
#         splits=[
#             '# Introduction',
#             'Many recent advances in natural language processing rely on large pre-trained language models, such as
# GPT-3 and 4 Brown et al. (2020); OpenAI (2023), Palm & Gemini Chowdhery et al. (2022); Team et al. (2023) and many
# others.',
#             'However, the rapid scientific progress in this area would be impossible without open-access LLMs such
# as LLaMA 1 and 2 (Touvron et al., 2023), Falcon (TII UAE, 2023), BLOOM (Scao et al., 2022), OPT (Zhang et al.,
# 2022), or NeoX/Pythia (Biderman et al., 2023).',
#             'The key advantage of open-access LLMs is that researchers can deploy them locally and modify them in
# ways that would be impossible with proprietary APIs.',
#             'Even though LLM parameters are openly available, it is still difficult to use these models due to
# their sheer size.',
#             'State-of-the-art open-access language models require multiple high-end GPUs 1 even for basic inference
# workloads.',
#             'To use these LLMs on more affordable hardware setups, one must either compress model parameters
# (Dettmers et al., 2022; Frantar et al., 2022) or offload parameters to a cheaper storage, be it RAM or SSD
# (Pudipeddi et al., 2020; Sheng et al., 2023).',
#             'Several recent works modify transformer architecture by introducing sparse Mixture-of-Experts blocks
# (Jacobs et al., 1991; Shazeer et al., 2017).',
#             'MoE blocks contain multiple â'
#         ],
#         is_triggered=True,
#         triggered_score=0.24572345751539332,
#         token_count=344,
#         metadata=None
#     )
# ]

# %%
def build_chunk(title: str, content: str):
    return f"# {title}\n{content}"

title = dataset[0]["title"]
for i, s in enumerate(chunks_0[0][:3]):
    content = Text(build_chunk(title=title, content=s.content))
    console.print(Panel(content, title=f"Chunk {i+1}", expand=False, border_style="bold"))
# Out:
# ╭──────────────────────────────────────────────────── Chunk 1 ────────────────────────────────────────────────────╮
# │ # Mixtral of Experts                                                                                            │
# │ 4 2 0 2 n a J 8 ] G L . s c [ 1 v 8 8 0 4 0 . 1 0 4 2 : v i X r a # Mixtral of Experts Albert Q. Jiang,         │
# │ Alexandre Sablayrolles, Antoine Roux, Arthur Mensch, Blanche Savary, Chris Bamford, Devendra Singh Chaplot,     │
# │ Diego de las Casas, Emma Bou Hanna, Florian Bressand, Gianna Lengyel, Guillaume Bour, Guillaume Lample, LÃ©lio  │
# │ Renard Lavaud, Lucile Saulnier, Marie-Anne Lachaux, Pierre Stock, Sandeep Subramanian, Sophia Yang, Szymon      │
# │ Antoniak, Teven Le Scao, ThÃ©ophile Gervet, Thibaut Lavril, Thomas Wang, TimothÃ©e Lacroix, William El Sayed    │
# │ Abstract We introduce Mixtral 8x7B, a Sparse Mixture of Experts (SMoE) language model. Mixtral has the same     │
# │ architecture as Mistral 7B, with the difference that each layer is composed of 8 feedforward blocks (i.e.       │
# │ experts). For every token, at each layer, a router network selects two experts to process the current state and │
# │ combine their outputs. Even though each token only sees two experts, the selected experts can be different at   │
# │ each timestep. As a result, each token has access to 47B parameters, but only uses 13B active parameters during │
# │ inference. Mixtral was trained with a context size of 32k tokens and it outperforms or matches Llama 2 70B and  │
# │ GPT-3.5 across all evaluated benchmarks. In particular, Mixtral vastly outperforms Llama 2 70B on mathematics,  │
# │ code generation, and multilingual benchmarks. We also provide a model fine- tuned to follow instructions,       │
# │ Mixtral 8x7B â Instruct, that surpasses GPT-3.5 Turbo, Claude-2.1, Gemini Pro, and Llama 2 70B â                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────────── Chunk 2 ────────────────────────────────────────────────────╮
# │ # Mixtral of Experts                                                                                            │
# │ chat model on human bench- marks. Both the base and instruct models are released under the Apache 2.0 license.  │
# │ Code: https://github.com/mistralai/mistral-src Webpage: https://mistral.ai/news/mixtral-of-experts/ #           │
# │ Introduction In this paper, we present Mixtral 8x7B, a sparse mixture of experts model (SMoE) with open         │
# │ weights, licensed under Apache 2.0. Mixtral outperforms Llama 2 70B and GPT-3.5 on most benchmarks. As it only  │
# │ uses a subset of its parameters for every token, Mixtral allows faster inference speed at low batch-sizes, and  │
# │ higher throughput at large batch-sizes. Mixtral is a sparse mixture-of-experts network. It is a decoder-only    │
# │ model where the feedforward block picks from a set of 8 distinct groups of parameters. At every layer, for      │
# │ every token, a router network chooses two of these groups (the â                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────────── Chunk 3 ────────────────────────────────────────────────────╮
# │ # Mixtral of Experts                                                                                            │
# │ expertsâ ) to process the token and combine their output additively. This technique increases the number of     │
# │ parameters of a model while controlling cost and latency, as the model only uses a fraction of the total set of │
# │ parameters per token. Mixtral is pretrained with multilingual data using a context size of 32k tokens. It       │
# │ either matches or exceeds the performance of Llama 2 70B and GPT-3.5, over several benchmarks. In particular,   │
# │ Mixture of Experts Layer i gating inputs af outputs router expert                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Add metadata to the chunks
#
# Since our chunks are statistical, we want to be able to retrieve neighboring chunks for the generator as part of the augmentation phase of the RAG. The metadata includes the original document and the adjacent chunks. Neighboring chunks refer to the chunks that come immediately before and after a given chunk in the original document sequence.

# %%
arxiv_id = dataset[0]["id"]
refs = list(dataset[0]["references"].values())

metadata = []
for i, s in enumerate(chunks_0[0]):
    prechunk = "" if i == 0 else chunks_0[0][i-1].content
    postchunk = "" if i+1 >= len(chunks_0[0]) else chunks_0[0][i+1].content
    metadata.append({
        "title": title,
        "content": s.content,
        "prechunk": prechunk,
        "postchunk": postchunk,
        "arxiv_id": arxiv_id,
        "references": refs
    })

# %%
def build_metadata(doc: dict, doc_splits):
    # get document level metadata first
    arxiv_id = doc["id"]
    title = doc["title"]
    refs = list(doc["references"].values())
    # init split level metadata list
    metadata = []
    for i, split in enumerate(doc_splits):
        # get neighboring chunks
        prechunk_id = "" if i == 0 else f"{arxiv_id}#{i-1}"
        postchunk_id = "" if i+1 >= len(doc_splits) else f"{arxiv_id}#{i+1}"
        # create dict and append to metadata list
        metadata.append({
            "id": f"{arxiv_id}#{i}",
            "title": title,
            "content": split.content,
            "prechunk_id": prechunk_id,
            "postchunk_id": postchunk_id,
            "arxiv_id": arxiv_id,
            "references": refs
        })
    return metadata

# %%
metadata = build_metadata(
    doc=dataset[0],
    doc_splits=chunks_0[0][:3]
)

# %%
console.print(metadata)
# Out:
# [
#     {
#         'id': '2401.04088#0',
#         'title': 'Mixtral of Experts',
#         'content': '4 2 0 2 n a J 8 ] G L . s c [ 1 v 8 8 0 4 0 . 1 0 4 2 : v i X r a # Mixtral of Experts Albert
# Q. Jiang, Alexandre Sablayrolles, Antoine Roux, Arthur Mensch, Blanche Savary, Chris Bamford, Devendra Singh
# Chaplot, Diego de las Casas, Emma Bou Hanna, Florian Bressand, Gianna Lengyel, Guillaume Bour, Guillaume Lample,
# LÃ©lio Renard Lavaud, Lucile Saulnier, Marie-Anne Lachaux, Pierre Stock, Sandeep Subramanian, Sophia Yang, Szymon
# Antoniak, Teven Le Scao, ThÃ©ophile Gervet, Thibaut Lavril, Thomas Wang, TimothÃ©e Lacroix, William El Sayed
# Abstract We introduce Mixtral 8x7B, a Sparse Mixture of Experts (SMoE) language model. Mixtral has the same
# architecture as Mistral 7B, with the difference that each layer is composed of 8 feedforward blocks (i.e. experts).
# For every token, at each layer, a router network selects two experts to process the current state and combine their
# outputs. Even though each token only sees two experts, the selected experts can be different at each timestep. As a
# result, each token has access to 47B parameters, but only uses 13B active parameters during inference. Mixtral was
# trained with a context size of 32k tokens and it outperforms or matches Llama 2 70B and GPT-3.5 across all
# evaluated benchmarks. In particular, Mixtral vastly outperforms Llama 2 70B on mathematics, code generation, and
# multilingual benchmarks. We also provide a model fine- tuned to follow instructions, Mixtral 8x7B â Instruct, that
# surpasses GPT-3.5 Turbo, Claude-2.1, Gemini Pro, and Llama 2 70B â',
#         'prechunk_id': '',
#         'postchunk_id': '2401.04088#1',
#         'arxiv_id': '2401.04088',
#         'references': ['1905.07830']
#     },
#     {
#         'id': '2401.04088#1',
#         'title': 'Mixtral of Experts',
#         'content': 'chat model on human bench- marks. Both the base and instruct models are released under the
# Apache 2.0 license. Code: https://github.com/mistralai/mistral-src Webpage:
# https://mistral.ai/news/mixtral-of-experts/ # Introduction In this paper, we present Mixtral 8x7B, a sparse mixture
# of experts model (SMoE) with open weights, licensed under Apache 2.0. Mixtral outperforms Llama 2 70B and GPT-3.5
# on most benchmarks. As it only uses a subset of its parameters for every token, Mixtral allows faster inference
# speed at low batch-sizes, and higher throughput at large batch-sizes. Mixtral is a sparse mixture-of-experts
# network. It is a decoder-only model where the feedforward block picks from a set of 8 distinct groups of
# parameters. At every layer, for every token, a router network chooses two of these groups (the â',
#         'prechunk_id': '2401.04088#0',
#         'postchunk_id': '2401.04088#2',
#         'arxiv_id': '2401.04088',
#         'references': ['1905.07830']
#     },
#     {
#         'id': '2401.04088#2',
#         'title': 'Mixtral of Experts',
#         'content': 'expertsâ ) to process the token and combine their output additively. This technique increases
# the number of parameters of a model while controlling cost and latency, as the model only uses a fraction of the
# total set of parameters per token. Mixtral is pretrained with multilingual data using a context size of 32k tokens.
# It either matches or exceeds the performance of Llama 2 70B and GPT-3.5, over several benchmarks. In particular,
# Mixture of Experts Layer i gating inputs af outputs router expert',
#         'prechunk_id': '2401.04088#1',
#         'postchunk_id': '',
#         'arxiv_id': '2401.04088',
#         'references': ['1905.07830']
#     }
# ]
